# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import string
from textblob import TextBlob
from gensim import matutils, models
import scipy.sparse

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.4f}'.format)
sns.set()

# %%
rel_path = '..\\dataset\\'

dir_list = os.listdir(rel_path)
print(type(dir_list))
print(len(dir_list))
print((dir_list[0]))
# Out:
# <class 'list'>
# 546
# df_review_AB Aviation.csv

# %%
df = pd.DataFrame()

for file in dir_list:
    df_temp = pd.read_csv(f'{rel_path}{file}', sep=';')
    
    ## --- concat
    df = pd.concat([df, df_temp], axis=0, join='outer', ignore_index=True)

# %%
df.columns
# Out:
# Index(['airline', 'id', 'review', 'rating', 'header', 'sub_header', 'author',
#        'time_published', 'Type Of Traveller', 'Seat Type', 'Route',
#        'Date Flown', 'Seat Comfort', 'Cabin Staff Service', 'Food & Beverages',
#        'Ground Service', 'Value For Money', 'Recommended', 'Aircraft',
#        'Inflight Entertainment', 'Wifi & Connectivity'],
#       dtype='object')

# %%
## --- preprocess

def search_city(x):
    try:
        x = re.compile(r'\(.*\)').search(x).group()
        x = x.replace('(','').replace(')','')
    except Exception as e:
        x = ''
    return x


def type_aircraft_search(x):
    if type(x) == type('a'):
        if ('A' in x) and ('Boeing' in x):
            x = 'A / Boeing'
        elif ('A' in x) or ('Boeing' in x):
            if ('A' in x):
                x = 'A'
            else:
                x = 'Boeing'
        elif 'Embraer' in x:
            x = 'Embraer'
    return x

df['verified'] = df['review'].apply(lambda x: x.split(' |')[0])
df['verified'] = df['verified'].str.replace('✅ ','')
df['rating_only'] = df['rating'].apply(lambda x: x.split('/')[0] if type(x)==type('a') else x)
df['rating_only'] = df['rating_only'].astype('float')
df['header'] = df['header'].str.replace('"','')
df['city'] = df['sub_header'].apply(lambda x: search_city(x))
df['type_aircraft'] = df['Aircraft'].apply(lambda x: type_aircraft_search(x))

# df.drop(labels='review', axis=1, inplace=True)
df.columns = [col_name.lower().replace(' ','_') for col_name in df.columns]

# %%
# create functions for cleaning purposes

def cleaning_text_round_1(text):
    '''lowercase, remove punctuation, special character, words with number, '''
    
    text = text.lower()
    text = re.compile(r'[%s]' % string.punctuation).sub('', text)
    text = text.replace('✅ ','')
    text = re.compile(r'\w*\d+\w*').sub('', text)
    return text


def cleaning_text_round_2(text):
    '''additional punctuation and non-sensical text'''
    
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

# %%
df['review_clean'] = np.vectorize(cleaning_text_round_1)(df['review'])
df['review_clean'] = np.vectorize(cleaning_text_round_2)(df['review_clean'])

# %%
# sentiment & polarity

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

df['polarity'] = df['review_clean'].apply(pol)
df['subjectivity'] = df['review_clean'].apply(sub)

# %%
def clean_date(date):
    split_date = date.split(' ')
    split_date[0] = split_date[0].replace('st', '').replace('nd', '').replace('rd', '').replace('th', '')
    date = ' '.join(split_date)
    return date
    
    
df['time_published'] = df['time_published'].apply(clean_date)
df['time_published'] = pd.to_datetime(df['time_published'], format='%d %B %Y')

# %%
df.head()
# Out:
#          airline            id  \
# 0    AB Aviation  anchor694481
# 1    AB Aviation  anchor666859
# 2    AB Aviation  anchor666802
# 3  Adria Airways  anchor685541
# 4  Adria Airways  anchor684542
#
#                                               review rating  \
# 0  ✅ Trip Verified |  Moroni to Moheli. Turned ou...   9/10
# 1  ✅ Trip Verified | Moroni to Anjouan. It is a v...   1/10
# 2  ✅ Trip Verified |  Anjouan to Dzaoudzi. A very...   1/10
# 3  Not Verified |  Please do a favor yourself and...   1/10
# 4  ✅ Trip Verified | Do not book a flight with th...   1/10
#
#                                 header  \
# 0                pretty decent airline
# 1                   Not a good airline
# 2         flight was fortunately short
# 3    I will never fly again with Adria
# 4  it ruined our last days of holidays
#
#                                           sub_header                   author  \
# 0        Tom Hansen (Netherlands) 11th November 2019               Tom Hansen
# 1  26 reviews Gyan Fernando (United Kingdom) 25th...  26 reviewsGyan Fernando
# 2  26 reviews Gyan Fernando (United Kingdom) 25th...  26 reviewsGyan Fernando
# 3        D Praetextatus (Serbia) 28th September 2019           D Praetextatus
# 4         D Meijer (Netherlands) 24th September 2019                 D Meijer
#
#   time_published type_of_traveller      seat_type  \
# 0     2019-11-11      Solo Leisure  Economy Class
# 1     2019-06-25      Solo Leisure  Economy Class
# 2     2019-06-25      Solo Leisure  Economy Class
# 3     2019-09-28      Solo Leisure  Economy Class
# 4     2019-09-24    Couple Leisure  Economy Class
#
#                               route      date_flown  seat_comfort  \
# 0                  Moroni to Moheli   November 2019        4.0000
# 1                 Moroni to Anjouan       June 2019        2.0000
# 2               Anjouan to Dzaoudzi       June 2019        2.0000
# 3             Frankfurt to Pristina  September 2019        1.0000
# 4  Sofia to Amsterdam via Ljubljana  September 2019        1.0000
#
#    cabin_staff_service  food_&_beverages  ground_service  value_for_money  \
# 0               5.0000            4.0000          4.0000           3.0000
# 1               2.0000            1.0000          1.0000           2.0000
# 2               1.0000            1.0000          1.0000           2.0000
# 3               1.0000               NaN          1.0000           1.0000
# 4               1.0000            1.0000          1.0000           1.0000
#
#   recommended      aircraft  inflight_entertainment  wifi_&_connectivity  \
# 0         yes           NaN                     NaN                  NaN
# 1          no          E120                     NaN                  NaN
# 2          no  Embraer E120                     NaN                  NaN
# 3          no           NaN                     NaN                  NaN
# 4          no           NaN                  1.0000               1.0000
#
#         verified  rating_only city type_aircraft  \
# 0  Trip Verified       9.0000                NaN
# 1  Trip Verified       1.0000               E120
# 2  Trip Verified       1.0000            Embraer
# 3   Not Verified       1.0000                NaN
# 4  Trip Verified       1.0000                NaN
#
#                                         review_clean  polarity  subjectivity
# 0  trip verified   moroni to moheli turned out to...    0.3022        0.6261
# 1  trip verified  moroni to anjouan it is a very ...   -0.0771        0.4183
# 2  trip verified   anjouan to dzaoudzi a very sma...    0.0458        0.5367
# 3  not verified   please do a favor yourself and ...   -0.1937        0.5823
# 4  trip verified  do not book a flight with this ...    0.1750        0.5229

# %%
df.describe(include='number')
# Out:
#        seat_comfort  cabin_staff_service  food_&_beverages  ground_service  \
# count   111335.0000          111255.0000        90427.0000      83895.0000
# mean         2.7936               3.0408            2.7804          2.4505
# std          1.4462               1.5856            1.4922          1.6003
# min          1.0000               1.0000            1.0000          1.0000
# 25%          1.0000               1.0000            1.0000          1.0000
# 50%          3.0000               3.0000            3.0000          2.0000
# 75%          4.0000               5.0000            4.0000          4.0000
# max          5.0000               5.0000            5.0000          5.0000
#
#        value_for_money  inflight_entertainment  wifi_&_connectivity  \
# count      123037.0000              73183.0000           27787.0000
# mean            2.7060                  2.6903               2.0058
# std             1.6027                  1.5073               1.4320
# min             1.0000                  1.0000               1.0000
# 25%             1.0000                  1.0000               1.0000
# 50%             3.0000                  3.0000               1.0000
# 75%             4.0000                  4.0000               3.0000
# max             5.0000                  5.0000               5.0000
#
#        rating_only    polarity  subjectivity
# count  121085.0000 125422.0000   125422.0000
# mean        4.6021      0.0894        0.5127
# std         3.4995      0.2134        0.1284
# min         1.0000     -1.0000        0.0000
# 25%         1.0000     -0.0392        0.4346
# 50%         3.0000      0.0803        0.5093
# 75%         8.0000      0.2250        0.5879
# max        10.0000      1.0000        1.0000

# %%
df.describe(exclude='number')
# Out:
# C:\Users\ichfa\AppData\Local\Temp\ipykernel_18732\1805651458.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(exclude='number')
#                   airline            id  \
# count              125422        125422
# unique                546        125343
# top     American Airlines  anchor317177
# freq                 5403             2
# first                 NaN           NaN
# last                  NaN           NaN
#
#                                                    review  rating  \
# count                                              125422  121085
# unique                                             125140      11
# top     Aug 28 from Baltimore to Boston. Check-in staf...    1/10
# freq                                                    2   41883
# first                                                 NaN     NaN
# last                                                  NaN     NaN
#
#                                  header  \
# count                            125422
# unique                            67831
# top     Spirit Airlines customer review
# freq                               1066
# first                               NaN
# last                                NaN
#
#                                                sub_header           author  \
# count                                              125422           125422
# unique                                             119325            89996
# top     29 reviews A Berlov (Russian Federation) 19th ...  Anders Pedersen
# freq                                                   26              251
# first                                                 NaN              NaN
# last                                                  NaN              NaN
#
#              time_published type_of_traveller      seat_type  \
# count                125422             87104         122401
# unique                 5076                 4              4
# top     2015-01-19 00:00:00      Solo Leisure  Economy Class
# freq                    297             31847          99298
# first   2002-01-06 00:00:00               NaN            NaN
# last    2023-01-05 00:00:00               NaN            NaN
#
#                       route   date_flown recommended aircraft       verified  \
# count                 86799        86951      125422    35242         125422
# unique                48318          107           2     3474          53784
# top     Sydney to Melbourne  August 2015          no     A320  Trip Verified
# freq                    144         1556       74526     4368          42579
# first                   NaN          NaN         NaN      NaN            NaN
# last                    NaN          NaN         NaN      NaN            NaN
#
#           city type_aircraft  \
# count   125422         35242
# unique       1           709
# top                        A
# freq    125422         16203
# first      NaN           NaN
# last       NaN           NaN
#
#                                              review_clean
# count                                              125422
# unique                                             125132
# top     rating   cabin flown economy value for money s...
# freq                                                    7
# first                                                 NaN
# last                                                  NaN

# %%
# drop unnecessary columns

df.drop(labels = ['id', 'review', 'rating', 'header', 'sub_header', 'author', 
                  'route', 'date_flown', 'aircraft', 'verified',
                 'city', 'type_aircraft'],
       axis=1,
       inplace=True)

# %%
df.head()
# Out:
#          airline time_published type_of_traveller      seat_type  \
# 0    AB Aviation     2019-11-11      Solo Leisure  Economy Class
# 1    AB Aviation     2019-06-25      Solo Leisure  Economy Class
# 2    AB Aviation     2019-06-25      Solo Leisure  Economy Class
# 3  Adria Airways     2019-09-28      Solo Leisure  Economy Class
# 4  Adria Airways     2019-09-24    Couple Leisure  Economy Class
#
#    seat_comfort  cabin_staff_service  food_&_beverages  ground_service  \
# 0        4.0000               5.0000            4.0000          4.0000
# 1        2.0000               2.0000            1.0000          1.0000
# 2        2.0000               1.0000            1.0000          1.0000
# 3        1.0000               1.0000               NaN          1.0000
# 4        1.0000               1.0000            1.0000          1.0000
#
#    value_for_money recommended  inflight_entertainment  wifi_&_connectivity  \
# 0           3.0000         yes                     NaN                  NaN
# 1           2.0000          no                     NaN                  NaN
# 2           2.0000          no                     NaN                  NaN
# 3           1.0000          no                     NaN                  NaN
# 4           1.0000          no                  1.0000               1.0000
#
#    rating_only                                       review_clean  polarity  \
# 0       9.0000  trip verified   moroni to moheli turned out to...    0.3022
# 1       1.0000  trip verified  moroni to anjouan it is a very ...   -0.0771
# 2       1.0000  trip verified   anjouan to dzaoudzi a very sma...    0.0458
# 3       1.0000  not verified   please do a favor yourself and ...   -0.1937
# 4       1.0000  trip verified  do not book a flight with this ...    0.1750
#
#    subjectivity
# 0        0.6261
# 1        0.4183
# 2        0.5367
# 3        0.5823
# 4        0.5229

# %%
# save file for dashboard purposes

df.to_csv(f'{rel_path}cleaned_df.csv', index=False)
