# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.4f}'.format)
sns.set()

# %%
rel_path = '..\\dataset\\'

dir_list = os.listdir(rel_path)
print(type(dir_list))
print(len(dir_list))
print((dir_list[0]))
# Out:
# <class 'list'>
# 546
# df_review_AB Aviation.csv

# %%
df = pd.DataFrame()

for file in dir_list:
    df_temp = pd.read_csv(f'{rel_path}{file}', sep=';')
    
    ## --- concat
    df = pd.concat([df, df_temp], axis=0, join='outer', ignore_index=True)

# %%
df.columns
# Out:
# Index(['airline', 'id', 'review', 'rating', 'header', 'sub_header', 'author',
#        'time_published', 'Type Of Traveller', 'Seat Type', 'Route',
#        'Date Flown', 'Seat Comfort', 'Cabin Staff Service', 'Food & Beverages',
#        'Ground Service', 'Value For Money', 'Recommended', 'Aircraft',
#        'Inflight Entertainment', 'Wifi & Connectivity', 'verified',
#        'rating_only', 'city'],
#       dtype='object')

# %%
## --- preprocess

def search_city(x):
    try:
        x = re.compile(r'\(.*\)').search(x).group()
        x = x.replace('(','').replace(')','')
    except Exception as e:
        x = ''
    return x


def type_aircraft_search(x):
    if type(x) == type('a'):
        if ('A' in x) and ('Boeing' in x):
            x = 'A / Boeing'
        elif ('A' in x) or ('Boeing' in x):
            if ('A' in x):
                x = 'A'
            else:
                x = 'Boeing'
        elif 'Embraer' in x:
            x = 'Embraer'
    return x

df['verified'] = df['review'].apply(lambda x: x.split(' |')[0])
df['verified'] = df['verified'].str.replace('✅ ','')
df['rating_only'] = df['rating'].apply(lambda x: x.split('/')[0] if type(x)==type('a') else x)
df['rating_only'] = df['rating_only'].astype('float')
df['header'] = df['header'].str.replace('"','')
df['city'] = df['sub_header'].apply(lambda x: search_city(x))
df['type_aircraft'] = df['Aircraft'].apply(lambda x: type_aircraft_search(x))

df.drop(labels='review', axis=1, inplace=True)
df.columns = [col_name.lower().replace(' ','_') for col_name in df.columns]

# %%
df.head()
# Out:
#          airline            id rating                               header  \
# 0    AB Aviation  anchor694481   9/10                pretty decent airline
# 1    AB Aviation  anchor666859   1/10                   Not a good airline
# 2    AB Aviation  anchor666802   1/10         flight was fortunately short
# 3  Adria Airways  anchor685541   1/10    I will never fly again with Adria
# 4  Adria Airways  anchor684542   1/10  it ruined our last days of holidays
#
#                                           sub_header                   author  \
# 0        Tom Hansen (Netherlands) 11th November 2019               Tom Hansen
# 1  26 reviews Gyan Fernando (United Kingdom) 25th...  26 reviewsGyan Fernando
# 2  26 reviews Gyan Fernando (United Kingdom) 25th...  26 reviewsGyan Fernando
# 3        D Praetextatus (Serbia) 28th September 2019           D Praetextatus
# 4         D Meijer (Netherlands) 24th September 2019                 D Meijer
#
#         time_published type_of_traveller      seat_type  \
# 0   11th November 2019      Solo Leisure  Economy Class
# 1       25th June 2019      Solo Leisure  Economy Class
# 2       25th June 2019      Solo Leisure  Economy Class
# 3  28th September 2019      Solo Leisure  Economy Class
# 4  24th September 2019    Couple Leisure  Economy Class
#
#                               route      date_flown  seat_comfort  \
# 0                  Moroni to Moheli   November 2019        4.0000
# 1                 Moroni to Anjouan       June 2019        2.0000
# 2               Anjouan to Dzaoudzi       June 2019        2.0000
# 3             Frankfurt to Pristina  September 2019        1.0000
# 4  Sofia to Amsterdam via Ljubljana  September 2019        1.0000
#
#    cabin_staff_service  food_&_beverages  ground_service  value_for_money  \
# 0               5.0000            4.0000          4.0000           3.0000
# 1               2.0000            1.0000          1.0000           2.0000
# 2               1.0000            1.0000          1.0000           2.0000
# 3               1.0000               NaN          1.0000           1.0000
# 4               1.0000            1.0000          1.0000           1.0000
#
#   recommended      aircraft  inflight_entertainment  wifi_&_connectivity  \
# 0         yes           NaN                     NaN                  NaN
# 1          no          E120                     NaN                  NaN
# 2          no  Embraer E120                     NaN                  NaN
# 3          no           NaN                     NaN                  NaN
# 4          no           NaN                  1.0000               1.0000
#
#         verified  rating_only city type_aircraft
# 0  Trip Verified       9.0000                NaN
# 1  Trip Verified       1.0000               E120
# 2  Trip Verified       1.0000            Embraer
# 3   Not Verified       1.0000                NaN
# 4  Trip Verified       1.0000                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125422 entries, 0 to 125421
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   airline                 125422 non-null  object
#  1   id                      125422 non-null  object
#  2   rating                  121085 non-null  object
#  3   header                  125422 non-null  object
#  4   sub_header              125422 non-null  object
#  5   author                  125422 non-null  object
#  6   time_published          125422 non-null  object
#  7   type_of_traveller       87104 non-null   object
#  8   seat_type               122401 non-null  object
#  9   route                   86799 non-null   object
#  10  date_flown              86951 non-null   object
#  11  seat_comfort            111335 non-null  float64
#  12  cabin_staff_service     111255 non-null  float64
#  13  food_&_beverages        90427 non-null   float64
#  14  ground_service          83895 non-null   float64
#  15  value_for_money         123037 non-null  float64
#  16  recommended             125422 non-null  object
#  17  aircraft                35242 non-null   object
#  18  inflight_entertainment  73183 non-null   float64
#  19  wifi_&_connectivity     27787 non-null   float64
#  20  verified                125422 non-null  object
#  21  rating_only             121085 non-null  float64
#  22  city                    125422 non-null  object
#  23  type_aircraft           35242 non-null   object
# dtypes: float64(8), object(16)
# memory usage: 23.0+ MB

# %%
df.describe(exclude='number')
# Out:
#                   airline            id  rating  \
# count              125422        125422  121085
# unique                546        125343      11
# top     American Airlines  anchor317177    1/10
# freq                 5403             2   41883
#
#                                  header  \
# count                            125422
# unique                            67831
# top     Spirit Airlines customer review
# freq                               1066
#
#                                                sub_header           author  \
# count                                              125422           125422
# unique                                             119325            89996
# top     29 reviews A Berlov (Russian Federation) 19th ...  Anders Pedersen
# freq                                                   26              251
#
#            time_published type_of_traveller      seat_type  \
# count              125422             87104         122401
# unique               5076                 4              4
# top     19th January 2015      Solo Leisure  Economy Class
# freq                  297             31847          99298
#
#                       route   date_flown recommended aircraft       verified  \
# count                 86799        86951      125422    35242         125422
# unique                48318          107           2     3474          53784
# top     Sydney to Melbourne  August 2015          no     A320  Trip Verified
# freq                    144         1556       74526     4368          42579
#
#           city type_aircraft
# count   125422         35242
# unique       1           709
# top                        A
# freq    125422         16203

# %%
df.drop(labels = ['rating', 'header', 'sub_header', 'author', 'route', 'date_flown', 
                  'aircraft', 'type_aircraft', 'city', 'verified'],
       axis=1,
       inplace=True)

# %%
def clean_date(date):
    split_date = date.split(' ')
    split_date[0] = split_date[0].replace('st', '').replace('nd', '').replace('rd', '').replace('th', '')
    date = ' '.join(split_date)
    return date
    
    
df['time_published'] = df['time_published'].apply(clean_date)
df['time_published'] = pd.to_datetime(df['time_published'], format='%d %B %Y')

# %%
df.head()
# Out:
#          airline            id time_published type_of_traveller  \
# 0    AB Aviation  anchor694481     2019-11-11      Solo Leisure
# 1    AB Aviation  anchor666859     2019-06-25      Solo Leisure
# 2    AB Aviation  anchor666802     2019-06-25      Solo Leisure
# 3  Adria Airways  anchor685541     2019-09-28      Solo Leisure
# 4  Adria Airways  anchor684542     2019-09-24    Couple Leisure
#
#        seat_type  seat_comfort  cabin_staff_service  food_&_beverages  \
# 0  Economy Class        4.0000               5.0000            4.0000
# 1  Economy Class        2.0000               2.0000            1.0000
# 2  Economy Class        2.0000               1.0000            1.0000
# 3  Economy Class        1.0000               1.0000               NaN
# 4  Economy Class        1.0000               1.0000            1.0000
#
#    ground_service  value_for_money recommended  inflight_entertainment  \
# 0          4.0000           3.0000         yes                     NaN
# 1          1.0000           2.0000          no                     NaN
# 2          1.0000           2.0000          no                     NaN
# 3          1.0000           1.0000          no                     NaN
# 4          1.0000           1.0000          no                  1.0000
#
#    wifi_&_connectivity  rating_only
# 0                  NaN       9.0000
# 1                  NaN       1.0000
# 2                  NaN       1.0000
# 3                  NaN       1.0000
# 4               1.0000       1.0000

# %%
df.to_csv(f'{rel_path}cleaned_df', index=False)
